# %% [markdown]
# # Llama Impact Hackathon
# This notebook contains the work for the Llama Impact Hackathon 2024.
# We will use the public complaints from the website https://ndreqe.com/reports

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import urllib.parse

# %%
# Read the config file for Together AI API key
import json
with open('configs.json', 'r') as file:
    config = json.load(file)

print('Configs Read!')

# %% [markdown]
# # Scraping the Data

# %%
# Scraping code here

# %% [markdown]
# # Reading the Data

# %%
# Read csv file
df = pd.read_csv('ndreqe.csv')

# Extract fields
df['municipality'] = df['web-scraper-start-url'].iloc[0][36:-10]
df['complaint_number'] = df['complaint-href'].str.rsplit('/', n=1).str[-1].astype(int)
df['image_url'] = df['images-src'].astype(str).apply(lambda x: 'https://ndreqe.com'+x)
df['image_url'] = df['image_url'].str.replace(r'(\.0)(\.jpeg)', r'\1.full\2', regex=True)
df['complaint'] = df['complaint'].apply(lambda x: x.replace('\n',' '))
df.rename(columns={'text':'title', 'tex2':'user_text'}, inplace=True)
df['municipality'] = df['municipality'].apply(lambda x: urllib.parse.unquote(x))
df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1731179571-1  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 1      1731179574-2  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 2      1731179574-3  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 3      1731179577-4  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 4      1731179577-5  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
#
#                                            complaint  \
# 0  Ndriçim publik          18:50,  7 Mar 2017,   ...
# 1  Ndriçim publik          17:09, 10 Mar 2017,   ...
# 2  Ndriçim publik          17:09, 10 Mar 2017,   ...
# 3  Ndriçim publik          04:57,  2 Pri 2017,   ...
# 4  Ndriçim publik          04:57,  2 Pri 2017,   ...
#
#                   complaint-href  \
# 0  https://ndreqe.com/report/171
# 1  https://ndreqe.com/report/189
# 2  https://ndreqe.com/report/189
# 3  https://ndreqe.com/report/365
# 4  https://ndreqe.com/report/365
#
#                                                title  \
# 0  Raportuar në kategorinë Ndriçim publik nga ano...
# 1  Raportuar në kategorinë Ndriçim publik nga ano...
# 2  Raportuar në kategorinë Ndriçim publik nga ano...
# 3  Raportuar në kategorinë Ndriçim publik nga ano...
# 4  Raportuar në kategorinë Ndriçim publik nga ano...
#
#                                            user_text  \
# 0  *Rruga ne lokacionin e shenuar nuk eshte shtru...
# 1           Drita nuk punon prej se eshte instaluar.
# 2           Drita nuk punon prej se eshte instaluar.
# 3     *Rruga Ferid Curri nuk ka fare ndriçim publik!
# 4     *Rruga Ferid Curri nuk ka fare ndriçim publik!
#
#                    images-src municipality  complaint_number  \
# 0  /photo/171.0.jpeg?876fef51   Prishtinës               171
# 1  /photo/189.0.jpeg?eefb909c   Prishtinës               189
# 2  /photo/189.1.jpeg?dd7ac08d   Prishtinës               189
# 3  /photo/365.0.jpeg?e7281615   Prishtinës               365
# 4  /photo/365.1.jpeg?6898da66   Prishtinës               365
#
#                                            image_url
# 0  https://ndreqe.com/photo/171.0.full.jpeg?876fef51
# 1  https://ndreqe.com/photo/189.0.full.jpeg?eefb909c
# 2       https://ndreqe.com/photo/189.1.jpeg?dd7ac08d
# 3  https://ndreqe.com/photo/365.0.full.jpeg?e7281615
# 4       https://ndreqe.com/photo/365.1.jpeg?6898da66

# %%
df['web-scraper-start-url'].iloc[0]
# Out:
# 'https://ndreqe.com/reports/Komuna+e+Prishtin%C3%ABs?t=unfixed'

# %%
df['web-scraper-start-url'].iloc[0][36:-10]
# Out:
# 'Prishtin%C3%ABs'

# %%
df.shape
# Out:
# (1469, 10)

# %%
df.columns
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'complaint',
#        'complaint-href', 'title', 'user_text', 'images-src', 'municipality',
#        'complaint_number', 'image_url'],
#       dtype='object')

# %%
df['web-scraper-start-url'].iloc[0]
# Out:
# 'https://ndreqe.com/reports/Komuna+e+Prishtin%C3%ABs?t=unfixed'

# %%
df['web-scraper-start-url'].value_counts()
# Out:
# web-scraper-start-url
# https://ndreqe.com/reports/Komuna+e+Prishtin%C3%ABs?t=unfixed    1469
# Name: count, dtype: int64

# %%
df.iloc[1].title
# Out:
# 'Raportuar në kategorinë Ndriçim publik nga anonim në 17:09, Pre 10 mars 2017'

# %%
df.iloc[1].user_text
# Out:
# 'Drita nuk punon prej se eshte instaluar.'

# %% [markdown]
# # Translation

# %%
# !pip install together
# Out:
# Collecting together
#   Downloading together-1.3.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.3 in /usr/local/lib/python3.10/dist-packages (from together) (3.10.10)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from together) (8.1.7)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from together) (0.2.0)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in /usr/local/lib/python3.10/dist-packages (from together) (3.16.1)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from together) (1.26.4)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /usr/local/lib/python3.10/dist-packages (from together) (10.4.0)
# Requirement already satisfied: pyarrow>=10.0.1 in /usr/local/lib/python3.10/dist-packages (from together) (17.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.3 in /usr/local/lib/python3.10/dist-packages (from together) (2.9.2)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from together) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=13.8.1 in /usr/local/lib/python3.10/dist-packages (from together) (13.9.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from together) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.2 in /usr/local/lib/python3.10/dist-packages (from together) (4.66.6)
# Requirement already satisfied: typer<0.13,>=0.9 in /usr/local/lib/python3.10/dist-packages (from together) (0.12.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.3->together) (4.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.3->together) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->together) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.8.1->together) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.8.1->together) (2.18.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13,>=0.9->together) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.8.1->together) (0.1.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.9.3->together) (0.2.0)
# Downloading together-1.3.3-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: together
# Successfully installed together-1.3.3

# %%
# Set up the LLM Client
from together import Together

client = Together(api_key=config['api_key'])
translation_model = "meta-llama/Llama-3.2-90B-Vision-Instruct-Turbo"

# %%
translation_system_prompt = 'Translate the following text to English. The answer should only contain the translated text, nothing else. The text is: '
text = """*Per hudhjen e mbeturinave ne kete vend kam njoftuar komunen se paku 3 here. Zyrtari i komunes ka vizituar vendin dhe ka premtuar se do te me njoftoje zyrtarisht per veprimet e metutjeshme te komunes. Deri me tani une nuk kam pranuar pergjigjje te tille (nje arsyetim se qenka prone e dikujt tjeter dhe se komuna nuk "paska te drejte" te pastroje token e huaj me eshte dhene permes telefonit. Asnje mirembajtje, sanim i ketij demi apo ndonje hap i metejshem nuk eshte nderrmare. Perndryshe ky vendbanim eshte ne nevoje urgjente edhe te nje rruge (per qasje ne objekt) si dhe per nje vendkalim te ngritur te kembesoreve per shkak te rrezikut te kalimit te rruges ne kete pjese!"""#"Raportuar në kategorinë Ndriçim publik nga anonim në 17:09, Pre 10 mars 2017"

# API call
response = client.chat.completions.create(
    model=translation_model,
    messages=[
        {
                "role": "user",
                "content": translation_system_prompt + text
        }
],
    temperature=0.5
)

translation = response.choices[0].message.content
print(translation)
# Out:
# Due to the accumulation of waste in this place, I have informed the commune at least 3 times. The commune official visited the site and promised to officially notify me of the commune's necessary actions. So far, I have not received such a response (an explanation that it is someone else's property and that the commune does not have the "right" to clean up someone else's land was given to me over the phone. No maintenance, cleaning of this area, or any further action has been taken. Otherwise, this settlement is in urgent need of a road (for access to the object) as well as a pedestrian crossing due to the danger of crossing the road in this part!

# %%
# Package the translation code into a function
def translate_text(text_to_translate):
  translation_system_prompt = 'Translate the following text to English. The answer should only contain the translated text, nothing else. The text is: '

  # API call
  response = client.chat.completions.create(
      model=translation_model,
      messages=[
          {
                  "role": "user",
                  "content": translation_system_prompt + text_to_translate
          }
  ],
      temperature=0.5
  )

  translation = response.choices[0].message.content
  time.sleep(1)
  return translation

print('Translation Function defined!')
# Out:
# Translation Function defined!

# %%
df.iloc[5].user_text
# Out:
# '*Per hudhjen e mbeturinave ne kete vend kam njoftuar komunen se paku 3 here. Zyrtari i komunes ka vizituar vendin dhe ka premtuar se do te me njoftoje zyrtarisht per veprimet e metutjeshme te komunes. Deri me tani une nuk kam pranuar pergjigjje te tille (nje arsyetim se qenka prone e dikujt tjeter dhe se komuna nuk "paska te drejte" te pastroje token e huaj me eshte dhene permes telefonit. Asnje mirembajtje, sanim i ketij demi apo ndonje hap i metejshem nuk eshte nderrmare. Perndryshe ky vendbanim eshte ne nevoje urgjente edhe te nje rruge (per qasje ne objekt) si dhe per nje vendkalim te ngritur te kembesoreve per shkak te rrezikut te kalimit te rruges ne kete pjese!'

# %%
# Obtaining subset of data - sample_df - to be used for testing throughout the notebook
sample_df = df.head(100).copy()
sample_df.tail()
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 95     1731179795-96  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 96     1731179798-97  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 97     1731179801-98  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 98     1731179804-99  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 99    1731179807-100  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
#
#                                 complaint                  complaint-href  \
# 95  Mbeturina          08:06, 27 Shk 2018  https://ndreqe.com/report/2669
# 96  Mbeturina          08:11, 27 Shk 2018  https://ndreqe.com/report/2670
# 97  Mbeturina          08:13, 27 Shk 2018  https://ndreqe.com/report/2671
# 98  Mbeturina          08:16, 27 Shk 2018  https://ndreqe.com/report/2672
# 99  Mbeturina          08:18, 27 Shk 2018  https://ndreqe.com/report/2673
#
#                                                 title  \
# 95  Raportuar në kategorinë Mbeturina nga anonim n...
# 96  Raportuar në kategorinë Mbeturina nga anonim n...
# 97  Raportuar në kategorinë Mbeturina nga anonim n...
# 98  Raportuar në kategorinë Mbeturina nga anonim n...
# 99  Raportuar në kategorinë Mbeturina nga anonim n...
#
#                                             user_text  \
# 95             *Matiqan, Prishtinë, Rrafsh i Kosovës.
# 96  *Muharrem Fejza, Matiqan, Prishtinë, Rrafsh i ...
# 97  *Muharrem Fejza, Matiqan, Prishtinë, Rrafsh i ...
# 98  *Ymer Elshani, Mati 1, Prishtinë, Rrafsh i Kos...
# 99  *Holger Petersen, Lagjja e Spitalit, Prishtinë...
#
#                      images-src municipality  complaint_number  \
# 95  /photo/2669.0.jpeg?2f1a4f38   Prishtinës              2669
# 96  /photo/2670.0.jpeg?157f488a   Prishtinës              2670
# 97  /photo/2671.0.jpeg?f286bf09   Prishtinës              2671
# 98  /photo/2672.0.jpeg?8ce0fd4b   Prishtinës              2672
# 99  /photo/2673.0.jpeg?85dd2582   Prishtinës              2673
#
#                                             image_url
# 95  https://ndreqe.com/photo/2669.0.full.jpeg?2f1a...
# 96  https://ndreqe.com/photo/2670.0.full.jpeg?157f...
# 97  https://ndreqe.com/photo/2671.0.full.jpeg?f286...
# 98  https://ndreqe.com/photo/2672.0.full.jpeg?8ce0...
# 99  https://ndreqe.com/photo/2673.0.full.jpeg?85dd...

# %%
sample_df['complaint_en'] = sample_df['complaint'].apply(translate_text)
sample_df['title_en'] = sample_df['title'].apply(translate_text)
sample_df['user_text_en'] = sample_df['user_text'].apply(translate_text)

sample_df
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 0       1731179571-1  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 1       1731179574-2  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 2       1731179574-3  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 3       1731179577-4  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 4       1731179577-5  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# ..               ...                                                ...
# 95     1731179795-96  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 96     1731179798-97  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 97     1731179801-98  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 98     1731179804-99  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 99    1731179807-100  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
#
#                                             complaint  \
# 0   Ndriçim publik          18:50,  7 Mar 2017,   ...
# 1   Ndriçim publik          17:09, 10 Mar 2017,   ...
# 2   Ndriçim publik          17:09, 10 Mar 2017,   ...
# 3   Ndriçim publik          04:57,  2 Pri 2017,   ...
# 4   Ndriçim publik          04:57,  2 Pri 2017,   ...
# ..                                                ...
# 95              Mbeturina          08:06, 27 Shk 2018
# 96              Mbeturina          08:11, 27 Shk 2018
# 97              Mbeturina          08:13, 27 Shk 2018
# 98              Mbeturina          08:16, 27 Shk 2018
# 99              Mbeturina          08:18, 27 Shk 2018
#
#                     complaint-href  \
# 0    https://ndreqe.com/report/171
# 1    https://ndreqe.com/report/189
# 2    https://ndreqe.com/report/189
# 3    https://ndreqe.com/report/365
# 4    https://ndreqe.com/report/365
# ..                             ...
# 95  https://ndreqe.com/report/2669
# 96  https://ndreqe.com/report/2670
# 97  https://ndreqe.com/report/2671
# 98  https://ndreqe.com/report/2672
# 99  https://ndreqe.com/report/2673
#
#                                                 title  \
# 0   Raportuar në kategorinë Ndriçim publik nga ano...
# 1   Raportuar në kategorinë Ndriçim publik nga ano...
# 2   Raportuar në kategorinë Ndriçim publik nga ano...
# 3   Raportuar në kategorinë Ndriçim publik nga ano...
# 4   Raportuar në kategorinë Ndriçim publik nga ano...
# ..                                                ...
# 95  Raportuar në kategorinë Mbeturina nga anonim n...
# 96  Raportuar në kategorinë Mbeturina nga anonim n...
# 97  Raportuar në kategorinë Mbeturina nga anonim n...
# 98  Raportuar në kategorinë Mbeturina nga anonim n...
# 99  Raportuar në kategorinë Mbeturina nga anonim n...
#
#                                             user_text  \
# 0   *Rruga ne lokacionin e shenuar nuk eshte shtru...
# 1            Drita nuk punon prej se eshte instaluar.
# 2            Drita nuk punon prej se eshte instaluar.
# 3      *Rruga Ferid Curri nuk ka fare ndriçim publik!
# 4      *Rruga Ferid Curri nuk ka fare ndriçim publik!
# ..                                                ...
# 95             *Matiqan, Prishtinë, Rrafsh i Kosovës.
# 96  *Muharrem Fejza, Matiqan, Prishtinë, Rrafsh i ...
# 97  *Muharrem Fejza, Matiqan, Prishtinë, Rrafsh i ...
# 98  *Ymer Elshani, Mati 1, Prishtinë, Rrafsh i Kos...
# 99  *Holger Petersen, Lagjja e Spitalit, Prishtinë...
#
#                      images-src municipality  complaint_number  \
# 0    /photo/171.0.jpeg?876fef51   Prishtinës               171
# 1    /photo/189.0.jpeg?eefb909c   Prishtinës               189
# 2    /photo/189.1.jpeg?dd7ac08d   Prishtinës               189
# 3    /photo/365.0.jpeg?e7281615   Prishtinës               365
# 4    /photo/365.1.jpeg?6898da66   Prishtinës               365
# ..                          ...          ...               ...
# 95  /photo/2669.0.jpeg?2f1a4f38   Prishtinës              2669
# 96  /photo/2670.0.jpeg?157f488a   Prishtinës              2670
# 97  /photo/2671.0.jpeg?f286bf09   Prishtinës              2671
# 98  /photo/2672.0.jpeg?8ce0fd4b   Prishtinës              2672
# 99  /photo/2673.0.jpeg?85dd2582   Prishtinës              2673
#
#                                             image_url  \
# 0   https://ndreqe.com/photo/171.0.full.jpeg?876fef51
# 1   https://ndreqe.com/photo/189.0.full.jpeg?eefb909c
# 2        https://ndreqe.com/photo/189.1.jpeg?dd7ac08d
# 3   https://ndreqe.com/photo/365.0.full.jpeg?e7281615
# 4        https://ndreqe.com/photo/365.1.jpeg?6898da66
# ..                                                ...
# 95  https://ndreqe.com/photo/2669.0.full.jpeg?2f1a...
# 96  https://ndreqe.com/photo/2670.0.full.jpeg?157f...
# 97  https://ndreqe.com/photo/2671.0.full.jpeg?f286...
# 98  https://ndreqe.com/photo/2672.0.full.jpeg?8ce0...
# 99  https://ndreqe.com/photo/2673.0.full.jpeg?85dd...
#
#                                          complaint_en  \
# 0   Public Domain          18:50,  7 Mar 2017,    ...
# 1   Public domain          17:09, 10 Mar 2017,    ...
# 2   Public release          17:09, 10 Mar 2017,   ...
# 3   Page protected 04:57,  2 Apr 2017,            ...
# 4   Public domain          04:57,  2 Apr 2017,    ...
# ..                                                ...
# 95              Mbeturina          08:06, 27 Aug 2018
# 96              Mbeturina          08:11, 27 Aug 2018
# 97              Mbeturina          08:13, 27 Sep 2018
# 98              Mbeturina          08:16, 27 Sep 2018
# 99              Mbeturina          08:18, 27 Aug 2018
#
#                                              title_en  \
# 0   Reported in Public Illumination category by an...
# 1   Reported in the Public Lighting category by an...
# 2   Reported in the Public Lighting category by an...
# 3   Reported in Public Lighting category by anonym...
# 4   Reported in the Public lighting category by an...
# ..                                                ...
# 95  Reported in the Litter category by anonymous a...
# 96  Reported in category Debris by anonymous at 08...
# 97  Reported in the Litter category by anonymous a...
# 98  Reported in the category Litter by anonymous a...
# 99  Reported in the Litter category by anonymous a...
#
#                                          user_text_en
# 0   The street with the designated location is not...
# 1     The light does not work since it was installed.
# 2     The light does not work since it was installed.
# 3   Ferid Curri Street does not have public lighting!
# 4          Ferid Curri Street has no public lighting!
# ..                                                ...
# 95                   Matiqan, Pristina, Kosovo Plain.
# 96   Muharrem Fejza, Matiqan, Pristina, Kosovo Plain.
# 97  Muharrem Fejza, Matiqan, Prishtina, Kosovo Plain.
# 98     Ymer Elshani, March 1, Pristina, Kosovo Plain.
# 99  Holger Petersen, Spital Hill, Pristina, Kosovo...
#
# [100 rows x 13 columns]

# %%
# for loop based code
# Initialize the new column with default values (e.g., None or 0)
sample_df['title_en2'] = None

# Iterate over the DataFrame rows using a for loop
for index, row in sample_df.iterrows():
    # Apply the function on the selected columns and assign the result
    sample_df.at[index, 'title_en2'] = translate_text(row['title'])

print(sample_df)

# works almost the same as apply

# %%
# Fetch date_created and date_modified
# Clean up extra spaces and handle case insensitivity
sample_df['complaint_en'] = sample_df['complaint_en'].str.replace(r'\s+', ' ', regex=True)  # Replace multiple spaces with single spaces
sample_df['complaint_en'] = sample_df['complaint_en'].str.strip()  # Remove leading/trailing spaces

# Regular expression to capture the two datetime patterns
sample_df[['date_created', 'date_modified']] = sample_df['complaint_en'].str.extract(
    r'(\d{2}:\d{2}, \d+ \w+ \d{4}).*?(\d{2}:\d{2}, \d+ \w+ \d{4})'
)

# Convert to datetime format
sample_df['date_created'] = pd.to_datetime(sample_df['date_created'], errors='coerce')
sample_df['date_modified'] = pd.to_datetime(sample_df['date_modified'], errors='coerce')

# Display the DataFrame
sample_df[['complaint_en','date_created', 'date_modified']].head()
# Out:
#                                         complaint_en        date_created  \
# 0  Public Domain 18:50, 7 Mar 2017, Last Update 1... 2017-03-07 18:50:00
# 1  Public domain 17:09, 10 Mar 2017, Last update ... 2017-03-10 17:09:00
# 2  Public release 17:09, 10 Mar 2017, Last update... 2017-03-10 17:09:00
# 3  Page protected 04:57, 2 Apr 2017, Last updated... 2017-04-02 04:57:00
# 4  Public domain 04:57, 2 Apr 2017, Last updated ... 2017-04-02 04:57:00
#
#         date_modified
# 0 2017-03-09 16:00:00
# 1 2017-03-17 08:37:00
# 2 2017-03-17 08:37:00
# 3 2017-04-03 09:22:00
# 4 2017-04-03 09:22:00

# %%
sample_df.to_csv('sample_df-1-translation.csv', index=False)
print('File saved successfully!')
# Out:
# File saved successfully!

# %%
sample_df.drop(columns=['title_en2'], inplace=True)
sample_df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1731179571-1  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 1      1731179574-2  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 2      1731179574-3  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 3      1731179577-4  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
# 4      1731179577-5  https://ndreqe.com/reports/Komuna+e+Prishtin%C...
#
#                                            complaint  \
# 0  Ndriçim publik          18:50,  7 Mar 2017,   ...
# 1  Ndriçim publik          17:09, 10 Mar 2017,   ...
# 2  Ndriçim publik          17:09, 10 Mar 2017,   ...
# 3  Ndriçim publik          04:57,  2 Pri 2017,   ...
# 4  Ndriçim publik          04:57,  2 Pri 2017,   ...
#
#                   complaint-href  \
# 0  https://ndreqe.com/report/171
# 1  https://ndreqe.com/report/189
# 2  https://ndreqe.com/report/189
# 3  https://ndreqe.com/report/365
# 4  https://ndreqe.com/report/365
#
#                                                title  \
# 0  Raportuar në kategorinë Ndriçim publik nga ano...
# 1  Raportuar në kategorinë Ndriçim publik nga ano...
# 2  Raportuar në kategorinë Ndriçim publik nga ano...
# 3  Raportuar në kategorinë Ndriçim publik nga ano...
# 4  Raportuar në kategorinë Ndriçim publik nga ano...
#
#                                            user_text  \
# 0  *Rruga ne lokacionin e shenuar nuk eshte shtru...
# 1           Drita nuk punon prej se eshte instaluar.
# 2           Drita nuk punon prej se eshte instaluar.
# 3     *Rruga Ferid Curri nuk ka fare ndriçim publik!
# 4     *Rruga Ferid Curri nuk ka fare ndriçim publik!
#
#                    images-src municipality  complaint_number  \
# 0  /photo/171.0.jpeg?876fef51   Prishtinës               171
# 1  /photo/189.0.jpeg?eefb909c   Prishtinës               189
# 2  /photo/189.1.jpeg?dd7ac08d   Prishtinës               189
# 3  /photo/365.0.jpeg?e7281615   Prishtinës               365
# 4  /photo/365.1.jpeg?6898da66   Prishtinës               365
#
#                                            image_url  \
# 0  https://ndreqe.com/photo/171.0.full.jpeg?876fef51
# 1  https://ndreqe.com/photo/189.0.full.jpeg?eefb909c
# 2       https://ndreqe.com/photo/189.1.jpeg?dd7ac08d
# 3  https://ndreqe.com/photo/365.0.full.jpeg?e7281615
# 4       https://ndreqe.com/photo/365.1.jpeg?6898da66
#
#                                         complaint_en  \
# 0  Public Domain 18:50, 7 Mar 2017, Last Update 1...
# 1  Public domain 17:09, 10 Mar 2017, Last update ...
# 2  Public release 17:09, 10 Mar 2017, Last update...
# 3  Page protected 04:57, 2 Apr 2017, Last updated...
# 4  Public domain 04:57, 2 Apr 2017, Last updated ...
#
#                                             title_en  \
# 0  Reported in Public Illumination category by an...
# 1  Reported in the Public Lighting category by an...
# 2  Reported in the Public Lighting category by an...
# 3  Reported in Public Lighting category by anonym...
# 4  Reported in the Public lighting category by an...
#
#                                         user_text_en        date_created  \
# 0  The street with the designated location is not... 2017-03-07 18:50:00
# 1    The light does not work since it was installed. 2017-03-10 17:09:00
# 2    The light does not work since it was installed. 2017-03-10 17:09:00
# 3  Ferid Curri Street does not have public lighting! 2017-04-02 04:57:00
# 4         Ferid Curri Street has no public lighting! 2017-04-02 04:57:00
#
#         date_modified
# 0 2017-03-09 16:00:00
# 1 2017-03-17 08:37:00
# 2 2017-03-17 08:37:00
# 3 2017-04-03 09:22:00
# 4 2017-04-03 09:22:00
